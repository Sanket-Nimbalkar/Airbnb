# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanky2151/Airbnb/blob/main/Airbnb_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - ***AirBnb Booking Analysis***

# %% [markdown]
# ##### **Project Type**    - **EDA**
# ##### **Contribution**    - * Aspiration DS Team
# ##### **Team Member 1 -**  Sanket Nimbalkar
# ##### **Team Member 2 -**  Chetan Gode
# ##### **Team Member 3 -**  Nikhil Thenge
# ##### **Team Member 4 -**  Harsh
# ##### **Team Member 5 -**  Pawan

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# #### AirBnb is a platform where people can rent their house to other people and earn money from people.AirBnb has provided different type of properites according to need of person to person.
#
# ####  In data set, there is available three different category of room ,with different location,area, rate of room,availability,hoster,service and other data available. So we have to find out best input from that data so it helps to expand AirBnb business and also provide good service to consumers.
# #### AirBnb nyc_2019 data set has approximate 49000 observation and 16 variable so we have to check all that data and give best output from that data.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Sanky2151/Airbnb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# #### Since 2008 Guest and Host used AirBnb to expand travelling possibility and present more unique and personalise way to experiencing the World.Today AirBnb become one of kind of service that is used and recognized by whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This data set has around 49,000 observations in it with 16 columns and it is mix of categorical and numeric values. Explore and analyse the data to discover key understandings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# #### Busineess Objective is simple to increase business by analyzing  data available.To help to take Big Decision easily, improving service and also find actual requirement of consumers.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
import missingno as msno
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/Airbnb NYC 2019.csv'
airbnb_df = pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
airbnb_df.duplicated().value_counts()
# Out:
# False    48895
# dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
airbnb_df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
msno.bar(airbnb_df)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset is about Airbnb dataset and we have to analysis data and find out insight from this.
# In our data set we have 48895 rows and 16 columns. Some of the columns have missing values like last_reviews, reviews per month, etc also we have to convert the format of last reviews from object to datatime.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
(airbnb_df[['price','minimum_nights','number_of_reviews','reviews_per_month', 'calculated_host_listings_count', 'availability_365']].describe())
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  48895.000000    48895.000000       48895.000000       38843.000000
# mean     152.720687        7.029962          23.274466           1.373221
# std      240.154170       20.510550          44.550582           1.680442
# min        0.000000        1.000000           0.000000           0.010000
# 25%       69.000000        1.000000           1.000000           0.190000
# 50%      106.000000        3.000000           5.000000           0.720000
# 75%      175.000000        5.000000          24.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# id-  Unique ID of properties that register in AirBnb.
#
# host_id - Unique id of host.
#
# host name - Name of the host
#
# neighbourhood_group- It is town/city.
#
# neighourhood - Local areas in town/city.
#
# room_types - Different types of room.
#
# price- Per day charges of room.
#
# minimum_nights- Minimum nights stay.
#
# number_of_reviews- Number of reviews of the room.
#
# last_review- Date of last reviews.
#
# reviews_per_month- The average Reviews per month.
#
# calculated_host_listings_count- total count show.
#
# availability_365 - Availability of room per year.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

airbnb_df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
# Check Unique Values for each variable.
# 1. 'id'
airbnb_df['id'].unique()
# Out:
# array([    2539,     2595,     3647, ..., 36485431, 36485609, 36487245])

# %%
# 2. 'name'
airbnb_df['name'].unique()
# Out:
# array(['Clean & quiet apt home by the park', 'Skylit Midtown Castle',
#        'THE VILLAGE OF HARLEM....NEW YORK !', ...,
#        'Sunny Studio at Historical Neighborhood',
#        '43rd St. Time Square-cozy single bed',
#        "Trendy duplex in the very heart of Hell's Kitchen"], dtype=object)

# %%
# 3. 'host_id'
airbnb_df['host_id'].unique()
# Out:
# array([     2787,      2845,      4632, ..., 274321313,  23492952,
#         68119814])

# %%
# 4. 'host_name'
airbnb_df['host_name'].unique()
# Out:
# array(['John', 'Jennifer', 'Elisabeth', ..., 'Abayomi', 'Alberth',
#        'Ilgar & Aysel'], dtype=object)

# %%
# 5. 'neighbourhood_group
airbnb_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
# 6. 'neighbourhood'
airbnb_df['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
# 7. 'latitude'
airbnb_df['latitude'].unique()
# Out:
# array([40.64749, 40.75362, 40.80902, ..., 40.80953, 40.70184, 40.81475])

# %%
# 8. 'longitude'
airbnb_df['longitude'].unique()
# Out:
# array([-73.97237, -73.98377, -73.9419 , ..., -73.87727, -73.93614,
#        -73.80844])

# %%
# 9. 'room_type'
airbnb_df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
# 10. 'price'
airbnb_df['price'].unique()
# Out:
# array([  149,   225,   150,    89,    80,   200,    60,    79,   135,
#           85,   120,   140,   215,    99,   190,   299,   130,   110,
#           44,   180,    50,    52,    55,    70,    35,    40,    68,
#          115,   151,   228,   144,    69,    49,   375,   250,   275,
#          230,    51,    65,   105,    95,   145,   285,    94,   800,
#          131,    98,   100,   125,   175,   500,   101,   220,    59,
#          350,   199,   325,   235,   170,   400,    75,    90,   185,
#           77,    76,   160,   195,   156,   219,   475,   165,   196,
#           83,   123,   265,   249,   121,    45,    71,    64,   159,
#          189,   239,   305,   155,    92,    36,    37,   205,    39,
#          390,   129,   212,   124,   122,   109,   575,   229,   169,
#          113,   179,   349,   139,   650,    67,   599,   211,   290,
#           87,   395,   260,    97,   132,   141,   495,   259,    96,
# ...

# %%
# 11. 'minimum_nights'
airbnb_df['minimum_nights'].unique()
# Out:
# array([   1,    3,   10,   45,    2,    5,    4,   90,    7,   14,   60,
#          29,   30,  180,    9,   31,    6,   15,    8,   26,   28,  200,
#          50,   17,   21,   11,   25,   13,   35,   27,   18,   20,   40,
#          44,   65,   55,  120,  365,  122,   19,  240,   88,  115,  150,
#         370,   16,   80,  181,  265,  300,   59,  185,  360,   56,   12,
#          70,   39,   24,   32, 1000,  110,  270,   22,   75,  250,   62,
#          23, 1250,  364,   74,  198,  100,  500,   43,   91,  480,   53,
#          99,  160,   47,  999,  186,  366,   68,   93,   87,  183,  299,
#         175,   98,  133,  354,   42,   33,   37,  225,  400,  105,  184,
#         153,  134,  222,   58,  210,  275,  182,  114,   85,   36])

# %%
# 12. 'number_of_reviews'
airbnb_df['number_of_reviews'].unique()
# Out:
# array([  9,  45,   0, 270,  74,  49, 430, 118, 160,  53, 188, 167, 113,
#         27, 148, 198, 260, 130,  39,  71,  88,  19,  58, 108,  29, 242,
#        197, 273, 168, 231, 214, 245,  15,  25,  81,  97,  11, 248,  61,
#        135, 112,  73,  82, 328, 105, 289, 138,  21,  42,   5,  66, 143,
#        191,   4, 338, 106, 190,  23, 142,  54,  70,  16,  94, 194,   2,
#        174,  24, 166,   1,  30, 139, 233,  68,  46, 335, 162, 170, 334,
#         12, 467,   7,  38, 324, 115, 354, 195,  13,  36,  63, 155, 193,
#         32,  50,  26, 426, 227,  84,   3,  10, 124, 240, 200,  79,  34,
#        134, 126, 234, 202,  28, 309,  14,  80, 294, 150,  47, 219, 114,
#        213,  86,  18, 206, 122,  33,  52,  51, 199,  41, 109, 151, 285,
#        375,   6, 358, 226, 104, 204, 253, 129,  37,  69, 192,  17, 222,
#        205, 458, 183, 189, 127,  35, 171,  92, 238,  56, 111, 147, 177,
#        185,  62, 181, 333, 441, 279, 203, 210,  64, 132,  20,  67, 187,
# ...

# %%
# 13. 'last_review'
airbnb_df['last_review'].unique()
# Out:
# array(['2018-10-19', '2019-05-21', nan, ..., '2017-12-23', '2018-01-29',
#        '2018-03-29'], dtype=object)

# %%
# 14. 'availability_365'
airbnb_df['availability_365'].unique()
# Out:
# array([365, 355, 194,   0, 129, 220, 188,   6,  39, 314, 333,  46, 321,
#         12,  21, 249, 347, 364, 304, 233,  85,  75, 311,  67, 255, 284,
#        359, 269, 340,  22,  96, 345, 273, 309,  95, 215, 265, 192, 251,
#        302, 140, 234, 257,  30, 301, 294, 320, 154, 263, 180, 231, 297,
#        292, 191,  72, 362, 336, 116,  88, 224, 322, 324, 132, 295, 238,
#        209, 328,  38,   7, 272,  26, 288, 317, 207, 185, 158,   9, 198,
#        219, 342, 312, 243, 152, 137, 222, 346, 208, 279, 250, 164, 298,
#        260, 107, 199, 299,  20, 318, 216, 245, 189, 307, 310, 213, 278,
#         16, 178, 275, 163,  34, 280,   1, 170, 214, 248, 262, 339,  10,
#        290, 230,  53, 126,   3,  37, 353, 177, 246, 225,  18, 343, 326,
#        162, 240, 363, 247, 323, 125,  91, 286,  60,  58, 351, 201, 232,
#        258, 341, 244, 329, 253, 348,   2,  56,  68, 360,  76,  15, 226,
#        349,  11, 316, 281, 287,  14,  86, 261, 331,  51, 254, 103,  42,
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Replacing null values of name column with 'Not mentioned'
airbnb_df.fillna({'name':'Not Mentioned'}, inplace = True)

# %%
# Replacing null vaules/missing values of reviews_per_month with 0
airbnb_df.fillna({'reviews_per_month':0}, inplace= True)

# %%
# Taking only those price values which are more than 0
airbnb_df = airbnb_df.loc[airbnb_df['price']>0]

# %%
# missing some 'last_review' date so we assume last date of last reviews ie. "2019-07-08"
# Replacing that value
airbnb_df["last_review"].fillna("2019-07-08",inplace=True)
airbnb_df["last_review"]
# Out:
# <ipython-input-30-e74f22d64de2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_df["last_review"].fillna("2019-07-08",inplace=True)
# 0        2018-10-19
# 1        2019-05-21
# 2        2019-07-08
# 3        2019-07-05
# 4        2018-11-19
#             ...
# 48890    2019-07-08
# 48891    2019-07-08
# 48892    2019-07-08
# 48893    2019-07-08
# 48894    2019-07-08
# Name: last_review, Length: 48884, dtype: object

# %%
# converting date type (object) to datetime format of last review column
from datetime import datetime


airbnb_df['last_review']=airbnb_df['last_review'].apply(lambda x : datetime.strptime(x,'%Y-%m-%d'))
airbnb_df['last_review']
# Out:
# 0       2018-10-19
# 1       2019-05-21
# 2       2019-07-08
# 3       2019-07-05
# 4       2018-11-19
#            ...
# 48890   2019-07-08
# 48891   2019-07-08
# 48892   2019-07-08
# 48893   2019-07-08
# 48894   2019-07-08
# Name: last_review, Length: 48884, dtype: datetime64[ns]

# %%
# Dataset info
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48884 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48884 non-null  int64
#  1   name                            48884 non-null  object
#  2   host_id                         48884 non-null  int64
#  3   host_name                       48863 non-null  object
#  4   neighbourhood_group             48884 non-null  object
#  5   neighbourhood                   48884 non-null  object
#  6   latitude                        48884 non-null  float64
#  7   longitude                       48884 non-null  float64
#  8   room_type                       48884 non-null  object
#  9   price                           48884 non-null  int64
#  10  minimum_nights                  48884 non-null  int64
#  11  number_of_reviews               48884 non-null  int64
# ...

# %%
# Dataset Describe
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.888400e+04  4.888400e+04  48884.000000  48884.000000  48884.000000
# mean   1.901679e+07  6.762203e+07     40.728953    -73.952176    152.755053
# std    1.098432e+07  7.861666e+07      0.054532      0.046159    240.170260
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.470548e+06  7.817310e+06     40.690100    -73.983080     69.000000
# 50%    1.967574e+07  3.079257e+07     40.723080    -73.955685    106.000000
# 75%    2.915297e+07  1.074344e+08     40.763120    -73.936290    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48884.000000       48884.000000       48884.000000
# mean         7.029887          23.271991           1.090800
# std         20.512224          44.551331           1.597213
# ...

# %%
# Finding room type count distribution
room_type_count = airbnb_df.groupby('room_type')['id'].count().reset_index().rename(columns = { 'id' :'Number of rooms'})
room_type_count
# Out:
#          room_type  Number of rooms
# 0  Entire home/apt            25407
# 1     Private room            22319
# 2      Shared room             1158

# %%
# Finding number of room with respect to neighbourhood group
neighbourhood_group = airbnb_df.groupby('neighbourhood_group')['id'].count().reset_index().rename(columns ={'id':'number of apartment'})
neighbourhood_group
# Out:
#   neighbourhood_group  number of apartment
# 0               Bronx                 1090
# 1            Brooklyn                20095
# 2           Manhattan                21660
# 3              Queens                 5666
# 4       Staten Island                  373

# %%
# Finding Top 20 highest number of room with respect to neighbourhood
neighbourhood_count= airbnb_df.groupby('neighbourhood')['id'].count().reset_index().sort_values(by='id', ascending= False).rename(columns={'id':'Apartment'}).head(20)
neighbourhood_count
# Out:
#           neighbourhood  Apartment
# 214        Williamsburg       3919
# 13   Bedford-Stuyvesant       3710
# 94               Harlem       2658
# 28             Bushwick       2462
# 202     Upper West Side       1971
# 95       Hell's Kitchen       1958
# 64         East Village       1853
# 201     Upper East Side       1798
# 51        Crown Heights       1564
# 127             Midtown       1545
# 61          East Harlem       1117
# 91           Greenpoint       1114
# 34              Chelsea       1113
# 119     Lower East Side        911
# 4               Astoria        900
# 206  Washington Heights        899
# 209        West Village        768
# 73   Financial District        744
# 74             Flatbush        621
# 41         Clinton Hill        572

# %%
# Getting overall room distribution
room_with_respect_to_neighbourhood = airbnb_df.groupby(['neighbourhood_group','room_type'])['id'].count().reset_index().rename(columns={'id':'apartment'})
df= room_with_respect_to_neighbourhood.pivot(index='neighbourhood_group', columns='room_type', values='apartment' )
df
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            379           651           60
# Brooklyn                        9558         10126          411
# Manhattan                      13198          7982          480
# Queens                          2096          3372          198
# Staten Island                    176           188            9

# %%
# Finding average price with respect to room type
room_type_price= airbnb_df.groupby(['room_type'])['price'].mean().reset_index()
room_type_price
# Out:
#          room_type       price
# 0  Entire home/apt  211.810918
# 1     Private room   89.809131
# 2      Shared room   70.248705

# %%
# Finding average price with respect to neighbourhood group
state_average_price = airbnb_df.groupby([ 'neighbourhood_group'])['price'].mean().reset_index()
state_average_price
# Out:
#   neighbourhood_group       price
# 0               Bronx   87.577064
# 1            Brooklyn  124.438915
# 2           Manhattan  196.884903
# 3              Queens   99.517649
# 4       Staten Island  114.812332

# %%
# Getting overall view of average price distribution
room_price_distribution = airbnb_df.groupby(['neighbourhood_group','room_type'])['price'].mean().reset_index()
room_price_distribution= room_price_distribution.pivot(index='neighbourhood_group', columns='room_type', values='price' )
room_price_distribution
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     127.506596     66.890937    59.800000
# Brooklyn                  178.346202     76.545428    50.773723
# Manhattan                 249.257994    116.776622    88.977083
# Queens                    147.050573     71.762456    69.020202
# Staten Island             173.846591     62.292553    57.444444

# %%
# Finding Top 10 most expensive neighbourhood
expensive_locality = airbnb_df.groupby(['neighbourhood'])['price'].mean().sort_values( ascending=False).head(10).reset_index()
expensive_locality
# Out:
#        neighbourhood       price
# 0     Fort Wadsworth  800.000000
# 1            Woodrow  700.000000
# 2            Tribeca  490.638418
# 3           Sea Gate  487.857143
# 4          Riverdale  442.090909
# 5       Prince's Bay  409.500000
# 6  Battery Park City  367.557143
# 7  Flatiron District  341.925000
# 8      Randall Manor  336.000000
# 9               NoHo  295.717949

# %%
# Finding Top 10 most affordable neighbourhood
affordable_locality= airbnb_df.groupby('neighbourhood')['price'].mean().sort_values( ascending=True).head(10).reset_index()
affordable_locality
# Out:
#     neighbourhood      price
# 0     Bull's Head  47.333333
# 1     Hunts Point  50.500000
# 2         Tremont  51.545455
# 3       Soundview  53.466667
# 4        New Dorp  57.000000
# 5       Bronxdale  57.105263
# 6  New Dorp Beach  57.400000
# 7      Grant City  57.666667
# 8         Concord  58.192308
# 9      Mount Eden  58.500000

# %%
# Finding Top 10 most reviewed property and there host name
most_reviewed_host = airbnb_df.groupby(['name','host_name'])['reviews_per_month'].max().reset_index().sort_values(by='reviews_per_month',ascending=False).head(10)
most_reviewed_host
# Out:
#                                                     name host_name  \
# 18814  Enjoy great views of the City in our Deluxe Room!   Row NYC
# 21287           Great Room in the heart of Times Square!   Row NYC
# 26271                 Lou's Palace-So much for so little    Louann
# 23818  JFK Comfort.5 Mins from JFK Private Bedroom & ...   Nalicia
# 23810      JFK 2 Comfort 5 Mins from JFK Private Bedroom   Nalicia
# 23812      JFK 3 Comfort 5 Mins from JFK Private Bedroom   Nalicia
# 15429  Cozy Room Family Home LGA Airport NO CLEANING FEE  Danielle
# 17455  Cute Tiny Room Family Home by LGA NO CLEANING FEE  Danielle
# 48172                                 “For Heaven Cakes”     Brent
# 41225        Studio Apartment 6 minutes from JFK Airport  Lakshmee
#
#        reviews_per_month
# 18814              58.50
# 21287              27.95
# 26271              20.94
# 23818              19.75
# 23810              17.82
# 23812              16.81
# 15429              16.22
# ...

# %%
# Finding minimum average stay with respect to room type
minimum_stays = airbnb_df.groupby('room_type')['minimum_nights'].mean()
minimum_stays
# Out:
# room_type
# Entire home/apt    8.507262
# Private room       5.379004
# Shared room        6.434370
# Name: minimum_nights, dtype: float64

# %%
# Finding availablility of room per year with respect to neighbourhood group
airbnb_df = airbnb_df.loc[airbnb_df['availability_365']<366]
availability_room = airbnb_df.groupby(['neighbourhood_group'])['availability_365'].mean().reset_index().rename(columns={'availability_365':'Available per year'})
availability_room
# Out:
#   neighbourhood_group  Available per year
# 0               Bronx          165.794495
# 1            Brooklyn          100.217318
# 2           Manhattan          111.984580
# 3              Queens          144.451818
# 4       Staten Island          199.678284

# %%
# Finding most expensive property and their details
expensive_host = airbnb_df.groupby(['name','neighbourhood_group','neighbourhood','room_type'])['price'].max().reset_index().sort_values(by='price', ascending=False).head(10)
expensive_host
# Out:
#                                                     name neighbourhood_group  \
# 27021    Luxury 1 bedroom apt. -stunning Manhattan views            Brooklyn
# 1109                                 1-BR Lincoln Center           Manhattan
# 20060                Furnished room in Astoria apartment              Queens
# 40732                                 Spanish Harlem Apt           Manhattan
# 35881                Quiet, Clean, Lit @ LES & Chinatown           Manhattan
# 2217   2br - The Heart of NYC: Manhattans Lower East ...           Manhattan
# 7054   Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho           Manhattan
# 19574                                      Film Location            Brooklyn
# 18227          East 72nd Townhouse by (Hidden by Airbnb)           Manhattan
# 20303                               Gem of east Flatbush            Brooklyn
#
#          neighbourhood        room_type  price
# 27021       Greenpoint  Entire home/apt  10000
# ...

# %%
# Finding most affordable property and their details
most_affordable_host = airbnb_df.groupby(['name','neighbourhood_group','neighbourhood','room_type'])['price'].min().reset_index().sort_values(by='price', ascending=True).head(10)
most_affordable_host
# Out:
#                                                     name neighbourhood_group  \
# 16628                 Cozy room in a three-bedroom House              Queens
# 14029               Couch in Harlem Harvey Refugees only           Manhattan
# 20373  Girls only, cozy room one block from Times Square           Manhattan
# 20357  Gigantic Sunny Room in Park Slope-Private Back...            Brooklyn
# 23396                            IT'S SIMPLY CONVENIENT!              Queens
# 23761                                            Jen Apt           Manhattan
# 35889             Quiet, Cozy UES Studio Near the Subway           Manhattan
# 16208                           Cozy feel at home studio           Manhattan
# 38981      Spacious 2-bedroom Apt in Heart of Greenpoint            Brooklyn
# 25250      Large furnished 2 bedrooms- - 30 days Minimum           Manhattan
#
#          neighbourhood        room_type  price
# 16628        Woodhaven     Private room     10
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Room count distribution
# 2. Price distribution
# 3. Top 10 expensive properties
# 4. Top 10 affordable properties
# 5. Top 10 reviewed properties
# 6. Average minimum stays
# 7. Availability of room per year

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.pie(room_type_count['Number of rooms'],labels= room_type_count['room_type'], autopct= '%1.f%%', explode=[0, 0, 0.5], shadow=True )
# plt.legend()
plt.show()

plt.subplot(1,2,2)
plt.bar(room_type_count['room_type'], room_type_count['Number of rooms'], width=0.5)
plt.xticks(rotation=45)
plt.xlabel('Room type')
plt.ylabel('No. of rooms')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have use pie chart and bar graph to know exact percentage wise and also exact number wise comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we can see Entire home/apt have major share in AirBnb compare to private and shared rooms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10,5))
plt.xlabel("Price")
plt.ylabel("Frequency")
graph = sns.kdeplot(airbnb_df.price, color="Red", shade = True)
plt.title('Distribution of Price',size = 15)
plt.show()
# Out:
# <ipython-input-49-80357ed7526a>:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   graph = sns.kdeplot(airbnb_df.price, color="Red", shade = True)

# %%
x= 'neighbourhood_group'
y= 'price'
title = 'Price per Neighbourhood Group'

f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=x, y=y, data=airbnb_df)
plt.title(title)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In Kernel Distribution Estimation Plot we can see overall price distribution and in box plot we can easily see price distribution with respect to neighbourhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see in kde plot there is high frequency in 0-500 price range.
# In box plot we can see Manhattan have high price distribution and Bronx have low price distribution.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

plt.plot(neighbourhood_group['neighbourhood_group'],neighbourhood_group['number of apartment'])
plt.title('Room counts with respect to neighbourhood group')
plt.ylabel('No of rooms')
plt.xlabel('neighbourhood group')
plt.rcParams['figure.figsize'] = (10, 5)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used plot chart to show exact comparison of room count with respect to neighbourhood group and we can easily see the comparison here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see Manhattan have most number of rooms followed by Brooklyn and Staten island have least.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

plt.figure(figsize=(10, 5))
sns.barplot(x='neighbourhood', y='Apartment', data=neighbourhood_count)
plt.xticks(rotation=90)
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Rooms')
plt.title('Room distribution with respect to Neighbourhood')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have picked here bar graph chart to show Top 20 neighbourhood with respect to room count.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see williamsburg have most rooms followed by Bedford-Stuyvesant.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
df= room_with_respect_to_neighbourhood.pivot(index='neighbourhood_group', columns='room_type', values='apartment' )
df.plot(kind='barh', figsize=(16,8))
plt.xlabel('Room count')
plt.ylabel('Neighbourhood group')
plt.title('Overall view of Room distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have picked here group horizontal bar graph to get overall view of room count with type of rooms with respect to neighbourhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see that all neighbourhood group have high count of private rooms except Manhattan. In manhattan most rooms are Entire home/apt type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 5 visualization code
sns.displot(
  data=airbnb_df,
  x="price",
  col="room_type",
  kind="hist",
  aspect=1.4,
  log_scale= 10,
  bins=20
)
plt.show()

# %%
# plotting barplot
sns.barplot(  x=room_type_price['room_type'],y=room_type_price['price'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. I have picked displot to get view of price distribution with respect to room type.
# 2. I have picked barplot to compare average price with room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. We can see that most private rooms, Entire home/apt and shared rooms are listed in 80-90,130-150 and 45-55 range respectively.
# 2. We can see average price of Entire home/apt is high compare to other room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(state_average_price['neighbourhood_group'], state_average_price['price'])
plt.title('Average price with respect to neighbourhood group')
plt.ylabel('Average price')
plt.xlabel('neighbourhood group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have picked plot graph chart compare average price of room with respect to neighbourhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can clearly see that average price is highest in Manhattan and lowest in Bronx.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

room_price_distribution.plot(kind='bar', figsize=(16,6))
plt.xlabel('Neighobourhood group')
plt.ylabel('Average price')
plt.title('Overall view of Average price distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have picked group bar graph to get overall view of average price within room type with respect to neighbourhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that in Entire home/apt Manhattan have highest average price and in shared room Brooklyn have lowest average price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

plt.subplot(1, 2, 1)
plt.plot(expensive_locality['neighbourhood'], expensive_locality['price'])
plt.title('Expensive locality')
plt.xticks(rotation=45)
plt.ylabel('Average price')
plt.xlabel('Neighbourhood')
plt.rcParams['figure.figsize'] = (10, 5)




plt.subplot(1, 2, 2)
plt.plot(affordable_locality['neighbourhood'], affordable_locality['price'])
plt.title('Affordable locality')
plt.xticks(rotation=45)
plt.ylabel('Average price')
plt.xlabel('Neighbourhood')
plt.rcParams['figure.figsize'] = (10, 5)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here i have picked the plot chart to compare most expensive and most affordable locality and we can easily see that.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Most expensive locality :- Fort Wadsworth
# 2. Most affordable locality :- Bull's Head

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(15,8))
sns.scatterplot(y=airbnb_df['price'],x=airbnb_df['minimum_nights'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here i have chosen scatter chart to show price distribution with respect to minimum nights

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that most of higher price are in minimum stays

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

sns.barplot(x=most_reviewed_host['name'], y=most_reviewed_host['reviews_per_month'])
plt.xticks(rotation=90)
plt.xlabel('Property name')
plt.ylabel('Number of reviews per month')
plt.title('Number of reviews per month with respect to property')
plt.legend( most_reviewed_host['host_name'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have chosen bar graph to show Top 10 most reviewed host and there property name.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Row Nyc named host is most reviewd host and his/her name is 'Enjoy great views of the city in our Deluxe room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.bar(expensive_host['name'], expensive_host['price'])
plt.xticks(rotation=90)
plt.xlabel('Property name')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Again i have picked bar graph to show most expensive property.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most expensive property name is Furnished room in Astoria apartment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize = (16,8))
sns.heatmap(airbnb_df.corr(), annot=True)
plt.show()
# Out:
# <ipython-input-62-847ada2ad715>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(airbnb_df.corr(), annot=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out corrleation between them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Pair Plot

# %%
# Chart - 14 visualization code
df2 = airbnb_df[['latitude','longitude', 'price', 'minimum_nights', 'number_of_reviews', 'availability_365', 'room_type' ]]

# %%
df_plot = sns.pairplot(df2.sample(1000), hue = "room_type", palette="husl")
print(df_plot)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have picked this chart to get overall view of all numerical values in the data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# 1. As we can see some cities and there local areas have less demand so we can make some strategies for increasing demand with help of marketing.
# 2. We have seen that shared rooms have less demands so we can enourage customers with help of discounting.
# 3. We can give recognition with awards or prizes to top 10 hosts.
# 4. In high demanding areas we can increase listing of rooms and also roll out some offers during festive season for longer stays which lead to business growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# #####From given data we found that
# * There is highest number of booking of Entire home/apt and lowest number of share room.
# * At location Manhattan highest number of rooms booked and area is Williamsburg
# * Highest number of private room in "Brooklyn" and lowest are in "Staten Island"
# * Highest number of share room in "Manhattan" and lowest in "Staten Island".
# * Highest number of Entire home/apt  in  "Manhattan"  and lowest in "Staten Island".
# * Highest average rate neighbourhood group is "Manhattan" and lowest is "Bronx".
# * Highest average rate neighbourhood is "Fort Wadsworth ".
# * Lowest average rate is in "Bull's Head " neighbourhood.
# * Average minimum stay in Entire home/apt is 8.5 days,Shared room is 6.4 days and Private room is 5.3.
# * Most expensive property names are "Furnished room in Astoria apartment " in area "Astoria"," 1-BR Lincoln Center" in area "Upper West Side" and "Luxury 1 bedroom apt.
# * Most affordable property names are 'Very Spacious bedroom, steps from CENTRAL PARK',Quiet, Cozy UES Studio Near the Subway and Couch in Harlem Harvey Refugees only etc

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
